# %%
import pandas as pd

# %%
structured_train = pd.read_csv('train.csv')
print(len(structured_train))
structured_test = pd.read_csv('test.csv')
print(len(structured_test))
print(len(structured_train) + len(structured_test))
# Out:
# 359043
# 89761
# 448804

# %%
structured_train
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0       215414    18566742  27103162.0  38538786  2135-07-16 16:08:00
# 1       205452    16853729         NaN  30043998  2178-01-25 05:09:00
# 2       200705    16026698         NaN  39475313  2128-10-19 20:01:00
# 3        87038    15398519  25237915.0  35495155  2147-06-15 09:50:00
# 4       373626    16787687  23674090.0  31087259  2181-03-20 10:38:00
# ...        ...         ...         ...       ...                  ...
# 359038  113182    10249080         NaN  32475431  2116-01-19 23:41:00
# 359039  323227    17819662  21020261.0  31105287  2182-02-08 00:32:00
# 359040  129321    13199993  24770260.0  37954239  2185-03-02 19:21:00
# 359041  167557    10028683         NaN  31802829  2171-12-05 17:36:00
# 359042  300451    13723460  25859289.0  39195476  2161-10-09 20:46:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ...  \
# 0       2135-07-17 01:49:00          58      F         2132  NaN  ...
# 1       2178-01-25 07:05:00          91      F         2169  NaN  ...
# 2       2128-10-19 20:16:00          23      M         2128  NaN  ...
# 3       2147-06-15 15:55:00          57      M         2136  NaN  ...
# 4       2181-03-21 12:55:00          87      F         2176  NaN  ...
# ...                     ...         ...    ...          ...  ...  ...
# 359038  2116-01-19 23:55:00          29      M         2114  NaN  ...
# 359039  2182-02-08 03:31:00          52      M         2182  NaN  ...
# 359040  2185-03-04 15:48:00          37      M         2179  NaN  ...
# 359041  2171-12-05 17:42:00          35      F         2169  NaN  ...
# 359042  2161-10-10 01:26:00          87      M         2160  NaN  ...
#
#        ed_pain_last n_med n_medrecon  triage_MAP score_CCI score_CART  \
# 0          2.127651   5.0        2.0   97.333333         2          4
# 1          2.127651   2.0        3.0  118.333333         7          9
# 2          7.000000   1.0        1.0  116.000000         0         12
# 3          0.000000   7.0       10.0  100.000000        12         16
# 4          0.000000   6.0       13.0   87.000000        11          9
# ...             ...   ...        ...         ...       ...        ...
# 359038     0.000000   0.0        0.0   98.666667         0          0
# 359039     2.127651   2.0        7.0  115.333333         1          0
# 359040     0.000000   7.0        0.0  116.666667         0          0
# 359041     0.000000   3.0       10.0   85.000000         1          0
# 359042     0.000000   3.0        0.0   96.622249        18          9
#
#        score_REMS  score_NEWS  score_NEWS2  score_MEWS
# 0               3           1            1           1
# 1               8           1            0           1
# 2               4           4            4           4
# 3               7           5            3           3
# 4               6           0            0           0
# ...           ...         ...          ...         ...
# 359038          0           0            0           1
# 359039          4           0            0           1
# 359040          2           0            0           1
# 359041          0           0            0           1
# 359042          6           0            0           1
#
# [359043 rows x 126 columns]

# %%
df_ecg = pd.read_csv("master_dataset_ecg_NEW_v3.csv")
print(len(df_ecg))
df_ecg
# Out:
# 185378
#         level_0  visit_key  subject_id     hadm_id   stay_id  \
# 0             4     335318    10000032  25742920.0  35968195
# 1            12     335319    10000117  22927623.0  32642808
# 2            18     279333    10000285         NaN  36555703
# 3            23     111945    10000635         NaN  31767754
# 4            24     111946    10000635         NaN  38135254
# ...         ...        ...         ...         ...       ...
# 185373   448959     279330    19999442         NaN  30337261
# 185374   448960      56669    19999464  23033573.0  34571984
# 185375   448966     167405    19999784  24935234.0  37972930
# 185376   448967     167406    19999784  25715748.0  34149746
# 185377   448969     167408    19999828  25744818.0  32917002
#
#                      intime              outtime  anchor_age gender  \
# 0       2180-08-05 20:58:00  2180-08-06 01:44:00          52      F
# 1       2181-11-14 21:51:00  2181-11-15 02:06:42          48      F
# 2       2161-11-08 14:19:00  2161-11-08 14:24:00          34      M
# 3       2138-09-29 10:54:00  2138-09-29 11:05:00          74      F
# 4       2141-08-15 11:32:00  2141-08-15 11:41:00          74      F
# ...                     ...                  ...         ...    ...
# 185373  2149-09-07 18:19:00  2149-09-07 18:26:00          41      M
# 185374  2171-08-01 15:12:00  2171-08-01 19:31:00          35      F
# 185375  2119-07-09 17:38:00  2119-07-10 00:04:00          57      M
# 185376  2119-08-11 09:15:00  2119-08-11 13:40:00          57      M
# 185377  2149-01-08 09:11:00  2149-01-08 18:12:00          46      F
#
#         anchor_year  ... ed_heartrate_last ed_resprate_last ed_o2sat_last  \
# 0              2180  ...              91.0             18.0          99.0
# 1              2174  ...              85.0             21.0          98.0
# 2              2159  ...              82.0             16.0          96.0
# 3              2136  ...              55.0             16.0         100.0
# 4              2136  ...              58.0             17.0         100.0
# ...             ...  ...               ...              ...           ...
# 185373         2146  ...              74.0             16.0         100.0
# 185374         2160  ...              58.0             16.0         100.0
# 185375         2119  ...              76.0             16.0          99.0
# 185376         2119  ...              72.0             16.0         100.0
# 185377         2147  ...             109.0             15.0          96.0
#
#        ed_sbp_last ed_dbp_last ed_pain_last n_med n_medrecon  \
# 0             98.0        60.0          NaN   6.0        7.0
# 1            141.0        77.0          0.0   0.0        1.0
# 2            123.0        80.0          5.0   5.0        0.0
# 3            122.0        70.0          0.0   1.0        5.0
# 4            122.0        65.0          0.0   1.0        6.0
# ...            ...         ...          ...   ...        ...
# 185373       120.0        82.0          0.0   4.0        2.0
# 185374       100.0        64.0          8.0   4.0        8.0
# 185375       142.0        80.0          3.0   0.0        1.0
# 185376       131.0        92.0          0.0   1.0        8.0
# 185377       111.0        78.0          4.0   8.0       11.0
#
#                                            ecg_paths  \
# 0       ['files/p1000/p10000032/s44458630/44458630']
# 1       ['files/p1000/p10000117/s45090959/45090959']
# 2       ['files/p1000/p10000285/s42709053/42709053']
# 3       ['files/p1000/p10000635/s43522917/43522917']
# 4       ['files/p1000/p10000635/s42947358/42947358']
# ...                                              ...
# 185373  ['files/p1999/p19999442/s49466572/49466572']
# 185374  ['files/p1999/p19999464/s44488939/44488939']
# 185375  ['files/p1999/p19999784/s40734999/40734999']
# 185376  ['files/p1999/p19999784/s47639679/47639679']
# 185377  ['files/p1999/p19999828/s40643529/40643529']
#
#                                    last_ecg_path
# 0       files/p1000/p10000032/s44458630/44458630
# 1       files/p1000/p10000117/s45090959/45090959
# 2       files/p1000/p10000285/s42709053/42709053
# 3       files/p1000/p10000635/s43522917/43522917
# 4       files/p1000/p10000635/s42947358/42947358
# ...                                          ...
# 185373  files/p1999/p19999442/s49466572/49466572
# 185374  files/p1999/p19999464/s44488939/44488939
# 185375  files/p1999/p19999784/s40734999/40734999
# 185376  files/p1999/p19999784/s47639679/47639679
# 185377  files/p1999/p19999828/s40643529/40643529
#
# [185378 rows x 122 columns]

# %%
df_notes = pd.read_csv("master_dataset_notes_cleaned_HOSPRED_ULTRA_256TOK_v3.csv")
print(len(df_notes))
df_notes
# Out:
# 242181
#          index  subject_id   stay_id  \
# 0       335315    10000032  38112554
# 1       335316    10000032  32952584
# 2       335318    10000032  35968195
# 3        56672    10000084  36954971
# 4       335319    10000117  32642808
# ...        ...         ...       ...
# 242176  391557    19999733  30940569
# 242177  167404    19999784  35692999
# 242178  167405    19999784  37972930
# 242179  167406    19999784  34149746
# 242180  167408    19999828  32917002
#
#                                                     notes  \
# 0       worsening abd distension and pain hcv cirrhosi...
# 1       abdominal fullness and discomfort with hiv on ...
# 2       altered mental status is a female with hiv on ...
# 3       male with disease dyslipidemia and a history o...
# 4       clinical history right upper quadrant pain eva...
# ...                                                   ...
# 242176  history woman with memory problem nausea heada...
# 242177  obstruction with modified barium swallow pendi...
# 242178  lle weakness dysphagia is a year old right han...
# 242179  intramedullary spinal cord lesion at the conus...
# 242180  enterocutaneous enteroatmospheric fistula is a...
#
#         outcome_hospitalization  outcome_critical
# 0                          True             False
# 1                          True              True
# 2                          True             False
# 3                          True             False
# 4                          True             False
# ...                         ...               ...
# 242176                     True             False
# 242177                     True             False
# 242178                     True             False
# 242179                     True             False
# 242180                     True              True
#
# [242181 rows x 6 columns]

# %%
df_notes.columns.to_list()
# Out:
# ['index',
#  'subject_id',
#  'stay_id',
#  'notes',
#  'outcome_hospitalization',
#  'outcome_critical']

# %%
conflict_hosp_notes = (
    df_notes.groupby("notes")["outcome_hospitalization"]
    .nunique()
    .loc[lambda x: x > 1]
    .index
)

# find notes with conflicting critical outcomes
conflict_crit_notes = (
    df_notes.groupby("notes")["outcome_critical"]
    .nunique()
    .loc[lambda x: x > 1]
    .index
)

# combine both sets
conflict_notes = set(conflict_hosp_notes).union(set(conflict_crit_notes))

print("Total conflicting note texts:", len(conflict_notes))

# remove them
df_notes_clean = df_notes[~df_notes["notes"].isin(conflict_notes)].copy()

print("Rows before:", len(df_notes))
print("Rows after:", len(df_notes_clean))
# Out:
# Total conflicting note texts: 575
# Rows before: 242181
# Rows after: 237933

# %%
df_notes
# Out:
#          index  subject_id   stay_id  \
# 0       335315    10000032  38112554
# 1       335316    10000032  32952584
# 2       335318    10000032  35968195
# 3        56672    10000084  36954971
# 4       335319    10000117  32642808
# ...        ...         ...       ...
# 242176  391557    19999733  30940569
# 242177  167404    19999784  35692999
# 242178  167405    19999784  37972930
# 242179  167406    19999784  34149746
# 242180  167408    19999828  32917002
#
#                                                     notes  \
# 0       worsening abd distension and pain hcv cirrhosi...
# 1       abdominal fullness and discomfort with hiv on ...
# 2       altered mental status is a female with hiv on ...
# 3       male with disease dyslipidemia and a history o...
# 4       clinical history right upper quadrant pain eva...
# ...                                                   ...
# 242176  history woman with memory problem nausea heada...
# 242177  obstruction with modified barium swallow pendi...
# 242178  lle weakness dysphagia is a year old right han...
# 242179  intramedullary spinal cord lesion at the conus...
# 242180  enterocutaneous enteroatmospheric fistula is a...
#
#         outcome_hospitalization  outcome_critical
# 0                          True             False
# 1                          True              True
# 2                          True             False
# 3                          True             False
# 4                          True             False
# ...                         ...               ...
# 242176                     True             False
# 242177                     True             False
# 242178                     True             False
# 242179                     True             False
# 242180                     True              True
#
# [242181 rows x 6 columns]

# %%
df_ecg
# Out:
#         level_0  visit_key  subject_id     hadm_id   stay_id  \
# 0             4     335318    10000032  25742920.0  35968195
# 1            12     335319    10000117  22927623.0  32642808
# 2            18     279333    10000285         NaN  36555703
# 3            23     111945    10000635         NaN  31767754
# 4            24     111946    10000635         NaN  38135254
# ...         ...        ...         ...         ...       ...
# 185373   448959     279330    19999442         NaN  30337261
# 185374   448960      56669    19999464  23033573.0  34571984
# 185375   448966     167405    19999784  24935234.0  37972930
# 185376   448967     167406    19999784  25715748.0  34149746
# 185377   448969     167408    19999828  25744818.0  32917002
#
#                      intime              outtime  anchor_age gender  \
# 0       2180-08-05 20:58:00  2180-08-06 01:44:00          52      F
# 1       2181-11-14 21:51:00  2181-11-15 02:06:42          48      F
# 2       2161-11-08 14:19:00  2161-11-08 14:24:00          34      M
# 3       2138-09-29 10:54:00  2138-09-29 11:05:00          74      F
# 4       2141-08-15 11:32:00  2141-08-15 11:41:00          74      F
# ...                     ...                  ...         ...    ...
# 185373  2149-09-07 18:19:00  2149-09-07 18:26:00          41      M
# 185374  2171-08-01 15:12:00  2171-08-01 19:31:00          35      F
# 185375  2119-07-09 17:38:00  2119-07-10 00:04:00          57      M
# 185376  2119-08-11 09:15:00  2119-08-11 13:40:00          57      M
# 185377  2149-01-08 09:11:00  2149-01-08 18:12:00          46      F
#
#         anchor_year  ... ed_heartrate_last ed_resprate_last ed_o2sat_last  \
# 0              2180  ...              91.0             18.0          99.0
# 1              2174  ...              85.0             21.0          98.0
# 2              2159  ...              82.0             16.0          96.0
# 3              2136  ...              55.0             16.0         100.0
# 4              2136  ...              58.0             17.0         100.0
# ...             ...  ...               ...              ...           ...
# 185373         2146  ...              74.0             16.0         100.0
# 185374         2160  ...              58.0             16.0         100.0
# 185375         2119  ...              76.0             16.0          99.0
# 185376         2119  ...              72.0             16.0         100.0
# 185377         2147  ...             109.0             15.0          96.0
#
#        ed_sbp_last ed_dbp_last ed_pain_last n_med n_medrecon  \
# 0             98.0        60.0          NaN   6.0        7.0
# 1            141.0        77.0          0.0   0.0        1.0
# 2            123.0        80.0          5.0   5.0        0.0
# 3            122.0        70.0          0.0   1.0        5.0
# 4            122.0        65.0          0.0   1.0        6.0
# ...            ...         ...          ...   ...        ...
# 185373       120.0        82.0          0.0   4.0        2.0
# 185374       100.0        64.0          8.0   4.0        8.0
# 185375       142.0        80.0          3.0   0.0        1.0
# 185376       131.0        92.0          0.0   1.0        8.0
# 185377       111.0        78.0          4.0   8.0       11.0
#
#                                            ecg_paths  \
# 0       ['files/p1000/p10000032/s44458630/44458630']
# 1       ['files/p1000/p10000117/s45090959/45090959']
# 2       ['files/p1000/p10000285/s42709053/42709053']
# 3       ['files/p1000/p10000635/s43522917/43522917']
# 4       ['files/p1000/p10000635/s42947358/42947358']
# ...                                              ...
# 185373  ['files/p1999/p19999442/s49466572/49466572']
# 185374  ['files/p1999/p19999464/s44488939/44488939']
# 185375  ['files/p1999/p19999784/s40734999/40734999']
# 185376  ['files/p1999/p19999784/s47639679/47639679']
# 185377  ['files/p1999/p19999828/s40643529/40643529']
#
#                                    last_ecg_path
# 0       files/p1000/p10000032/s44458630/44458630
# 1       files/p1000/p10000117/s45090959/45090959
# 2       files/p1000/p10000285/s42709053/42709053
# 3       files/p1000/p10000635/s43522917/43522917
# 4       files/p1000/p10000635/s42947358/42947358
# ...                                          ...
# 185373  files/p1999/p19999442/s49466572/49466572
# 185374  files/p1999/p19999464/s44488939/44488939
# 185375  files/p1999/p19999784/s40734999/40734999
# 185376  files/p1999/p19999784/s47639679/47639679
# 185377  files/p1999/p19999828/s40643529/40643529
#
# [185378 rows x 122 columns]

# %%
structured_train
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0       215414    18566742  27103162.0  38538786  2135-07-16 16:08:00
# 1       205452    16853729         NaN  30043998  2178-01-25 05:09:00
# 2       200705    16026698         NaN  39475313  2128-10-19 20:01:00
# 3        87038    15398519  25237915.0  35495155  2147-06-15 09:50:00
# 4       373626    16787687  23674090.0  31087259  2181-03-20 10:38:00
# ...        ...         ...         ...       ...                  ...
# 359038  113182    10249080         NaN  32475431  2116-01-19 23:41:00
# 359039  323227    17819662  21020261.0  31105287  2182-02-08 00:32:00
# 359040  129321    13199993  24770260.0  37954239  2185-03-02 19:21:00
# 359041  167557    10028683         NaN  31802829  2171-12-05 17:36:00
# 359042  300451    13723460  25859289.0  39195476  2161-10-09 20:46:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ...  \
# 0       2135-07-17 01:49:00          58      F         2132  NaN  ...
# 1       2178-01-25 07:05:00          91      F         2169  NaN  ...
# 2       2128-10-19 20:16:00          23      M         2128  NaN  ...
# 3       2147-06-15 15:55:00          57      M         2136  NaN  ...
# 4       2181-03-21 12:55:00          87      F         2176  NaN  ...
# ...                     ...         ...    ...          ...  ...  ...
# 359038  2116-01-19 23:55:00          29      M         2114  NaN  ...
# 359039  2182-02-08 03:31:00          52      M         2182  NaN  ...
# 359040  2185-03-04 15:48:00          37      M         2179  NaN  ...
# 359041  2171-12-05 17:42:00          35      F         2169  NaN  ...
# 359042  2161-10-10 01:26:00          87      M         2160  NaN  ...
#
#        ed_pain_last n_med n_medrecon  triage_MAP score_CCI score_CART  \
# 0          2.127651   5.0        2.0   97.333333         2          4
# 1          2.127651   2.0        3.0  118.333333         7          9
# 2          7.000000   1.0        1.0  116.000000         0         12
# 3          0.000000   7.0       10.0  100.000000        12         16
# 4          0.000000   6.0       13.0   87.000000        11          9
# ...             ...   ...        ...         ...       ...        ...
# 359038     0.000000   0.0        0.0   98.666667         0          0
# 359039     2.127651   2.0        7.0  115.333333         1          0
# 359040     0.000000   7.0        0.0  116.666667         0          0
# 359041     0.000000   3.0       10.0   85.000000         1          0
# 359042     0.000000   3.0        0.0   96.622249        18          9
#
#        score_REMS  score_NEWS  score_NEWS2  score_MEWS
# 0               3           1            1           1
# 1               8           1            0           1
# 2               4           4            4           4
# 3               7           5            3           3
# 4               6           0            0           0
# ...           ...         ...          ...         ...
# 359038          0           0            0           1
# 359039          4           0            0           1
# 359040          2           0            0           1
# 359041          0           0            0           1
# 359042          6           0            0           1
#
# [359043 rows x 126 columns]

# %%
structured_test
# Out:
#         index  subject_id     hadm_id   stay_id               intime  \
# 0      335316    10000032  29079034.0  32952584  2180-07-22 16:24:00
# 1       56672    10000084  29888819.0  36954971  2160-12-27 18:32:00
# 2           0    10000115         NaN  38081480  2154-12-10 02:04:00
# 3      335319    10000117  22927623.0  32642808  2181-11-14 21:51:00
# 4      335320    10000117         NaN  30632130  2183-07-17 10:30:00
# ...       ...         ...         ...       ...                  ...
# 89756  223462    19999156  22917423.0  39012698  2123-01-27 13:13:00
# 89757  111942    19999175         NaN  34469189  2185-08-13 20:35:00
# 89758  448969    19999270         NaN  30502357  2184-02-11 21:11:00
# 89759   56670    19999466  21397174.0  30402875  2116-08-30 12:11:00
# 89760  167407    19999828  29734428.0  30712109  2147-07-17 17:18:00
#
#                    outtime  anchor_age gender  anchor_year  dod  ...  \
# 0      2180-07-23 05:54:00          52      F         2180  NaN  ...
# 1      2160-12-28 16:07:00          72      M         2160  NaN  ...
# 2      2154-12-10 02:16:00          24      M         2154  NaN  ...
# 3      2181-11-15 02:06:42          48      F         2174  NaN  ...
# 4      2183-07-17 10:40:00          48      F         2174  NaN  ...
# ...                    ...         ...    ...          ...  ...  ...
# 89756  2123-01-27 21:39:00          62      F         2123  NaN  ...
# 89757  2185-08-13 22:24:00          21      M         2185  NaN  ...
# 89758  2184-02-11 21:14:00          33      M         2184  NaN  ...
# 89759  2116-08-31 21:49:00          33      M         2116  NaN  ...
# 89760  2147-07-18 17:34:00          46      F         2147  NaN  ...
#
#       ed_pain_last n_med n_medrecon  triage_MAP score_CCI score_CART  \
# 0         0.000000   2.0       14.0   52.333333         6          4
# 1         0.000000   1.0        6.0   85.000000         4          9
# 2         0.000000   0.0        0.0   87.333333         0          0
# 3         0.000000   0.0        1.0  104.666667         1          4
# 4         0.000000   0.0        0.0   70.000000         1          8
# ...            ...   ...        ...         ...       ...        ...
# 89756     0.000000   1.0        1.0  104.333333         2          4
# 89757     2.127651   0.0        0.0   93.000000         0          0
# 89758     0.000000   0.0        0.0   71.000000         0          4
# 89759     0.000000   3.0        0.0  134.333333         0          0
# 89760     9.000000  11.0        8.0   85.666667         0          0
#
#       score_REMS  score_NEWS  score_NEWS2  score_MEWS
# 0              4           3            3           2
# 1              5           1            0           1
# 2              0           0            0           1
# 3              3           0            0           1
# 4              5           4            4           4
# ...          ...         ...          ...         ...
# 89756          3           0            0           1
# 89757          2           0            0           1
# 89758          0           1            1           1
# 89759          3           0            0           1
# 89760          2           1            1           1
#
# [89761 rows x 126 columns]

# %%
structured_train["split"] = "train"
structured_test["split"] = "test"

structured_full = pd.concat([structured_train, structured_test], ignore_index=True)

# %%
structured_full
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0       215414    18566742  27103162.0  38538786  2135-07-16 16:08:00
# 1       205452    16853729         NaN  30043998  2178-01-25 05:09:00
# 2       200705    16026698         NaN  39475313  2128-10-19 20:01:00
# 3        87038    15398519  25237915.0  35495155  2147-06-15 09:50:00
# 4       373626    16787687  23674090.0  31087259  2181-03-20 10:38:00
# ...        ...         ...         ...       ...                  ...
# 448799  223462    19999156  22917423.0  39012698  2123-01-27 13:13:00
# 448800  111942    19999175         NaN  34469189  2185-08-13 20:35:00
# 448801  448969    19999270         NaN  30502357  2184-02-11 21:11:00
# 448802   56670    19999466  21397174.0  30402875  2116-08-30 12:11:00
# 448803  167407    19999828  29734428.0  30712109  2147-07-17 17:18:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ... n_med  \
# 0       2135-07-17 01:49:00          58      F         2132  NaN  ...   5.0
# 1       2178-01-25 07:05:00          91      F         2169  NaN  ...   2.0
# 2       2128-10-19 20:16:00          23      M         2128  NaN  ...   1.0
# 3       2147-06-15 15:55:00          57      M         2136  NaN  ...   7.0
# 4       2181-03-21 12:55:00          87      F         2176  NaN  ...   6.0
# ...                     ...         ...    ...          ...  ...  ...   ...
# 448799  2123-01-27 21:39:00          62      F         2123  NaN  ...   1.0
# 448800  2185-08-13 22:24:00          21      M         2185  NaN  ...   0.0
# 448801  2184-02-11 21:14:00          33      M         2184  NaN  ...   0.0
# 448802  2116-08-31 21:49:00          33      M         2116  NaN  ...   3.0
# 448803  2147-07-18 17:34:00          46      F         2147  NaN  ...  11.0
#
#        n_medrecon  triage_MAP score_CCI score_CART score_REMS score_NEWS  \
# 0             2.0   97.333333         2          4          3          1
# 1             3.0  118.333333         7          9          8          1
# 2             1.0  116.000000         0         12          4          4
# 3            10.0  100.000000        12         16          7          5
# 4            13.0   87.000000        11          9          6          0
# ...           ...         ...       ...        ...        ...        ...
# 448799        1.0  104.333333         2          4          3          0
# 448800        0.0   93.000000         0          0          2          0
# 448801        0.0   71.000000         0          4          0          1
# 448802        0.0  134.333333         0          0          3          0
# 448803        8.0   85.666667         0          0          2          1
#
#         score_NEWS2  score_MEWS  split
# 0                 1           1  train
# 1                 0           1  train
# 2                 4           4  train
# 3                 3           3  train
# 4                 0           0  train
# ...             ...         ...    ...
# 448799            0           1   test
# 448800            0           1   test
# 448801            1           1   test
# 448802            0           1   test
# 448803            1           1   test
#
# [448804 rows x 127 columns]

# %%
len(structured_full)
# Out:
# 448804

# %%
structured_full["stay_id"].nunique()
# Out:
# 448804

# %%
structured_full = structured_full.merge(
    df_notes[["stay_id", "notes"]],
    on="stay_id",
    how="left"
)

structured_full = structured_full.merge(
    df_ecg[["stay_id", "ecg_paths"]],
    on="stay_id",
    how="left"
)

# %%
structured_full
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0       215414    18566742  27103162.0  38538786  2135-07-16 16:08:00
# 1       205452    16853729         NaN  30043998  2178-01-25 05:09:00
# 2       200705    16026698         NaN  39475313  2128-10-19 20:01:00
# 3        87038    15398519  25237915.0  35495155  2147-06-15 09:50:00
# 4       373626    16787687  23674090.0  31087259  2181-03-20 10:38:00
# ...        ...         ...         ...       ...                  ...
# 448799  223462    19999156  22917423.0  39012698  2123-01-27 13:13:00
# 448800  111942    19999175         NaN  34469189  2185-08-13 20:35:00
# 448801  448969    19999270         NaN  30502357  2184-02-11 21:11:00
# 448802   56670    19999466  21397174.0  30402875  2116-08-30 12:11:00
# 448803  167407    19999828  29734428.0  30712109  2147-07-17 17:18:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ...  \
# 0       2135-07-17 01:49:00          58      F         2132  NaN  ...
# 1       2178-01-25 07:05:00          91      F         2169  NaN  ...
# 2       2128-10-19 20:16:00          23      M         2128  NaN  ...
# 3       2147-06-15 15:55:00          57      M         2136  NaN  ...
# 4       2181-03-21 12:55:00          87      F         2176  NaN  ...
# ...                     ...         ...    ...          ...  ...  ...
# 448799  2123-01-27 21:39:00          62      F         2123  NaN  ...
# 448800  2185-08-13 22:24:00          21      M         2185  NaN  ...
# 448801  2184-02-11 21:14:00          33      M         2184  NaN  ...
# 448802  2116-08-31 21:49:00          33      M         2116  NaN  ...
# 448803  2147-07-18 17:34:00          46      F         2147  NaN  ...
#
#         triage_MAP score_CCI score_CART score_REMS score_NEWS score_NEWS2  \
# 0        97.333333         2          4          3          1           1
# 1       118.333333         7          9          8          1           0
# 2       116.000000         0         12          4          4           4
# 3       100.000000        12         16          7          5           3
# 4        87.000000        11          9          6          0           0
# ...            ...       ...        ...        ...        ...         ...
# 448799  104.333333         2          4          3          0           0
# 448800   93.000000         0          0          2          0           0
# 448801   71.000000         0          4          0          1           1
# 448802  134.333333         0          0          3          0           0
# 448803   85.666667         0          0          2          1           1
#
#        score_MEWS  split                                              notes  \
# 0               1  train                                                NaN
# 1               1  train  contrast material through percutaneous gastros...
# 2               4  train  left elbow the lateral radiograph of the elbow...
# 3               3  train  shortness of breath year old man with a histor...
# 4               0  train  multiple patients with same last name on the r...
# ...           ...    ...                                                ...
# 448799          1   test                                                NaN
# 448800          1   test                                                NaN
# 448801          1   test                                                NaN
# 448802          1   test                                                NaN
# 448803          1   test                                                NaN
#
#                                            ecg_paths
# 0                                                NaN
# 1       ['files/p1685/p16853729/s46473969/46473969']
# 2                                                NaN
# 3       ['files/p1539/p15398519/s40039409/40039409']
# 4       ['files/p1678/p16787687/s44626801/44626801']
# ...                                              ...
# 448799                                           NaN
# 448800                                           NaN
# 448801                                           NaN
# 448802                                           NaN
# 448803                                           NaN
#
# [448804 rows x 129 columns]

# %%
structured_full = structured_full[
    structured_full["notes"].notna() & structured_full["ecg_paths"].notna()
]

# %%
len(structured_full)
# Out:
# 162620

# %%
structured_full["subject_id"].nunique()
# Out:
# 62123

# %%
print(structured_full["outcome_hospitalization"].value_counts())
# Out:
# outcome_hospitalization
# True     96929
# False    65691
# Name: count, dtype: int64

# %%
# shuffle rows
structured_full = structured_full.sample(frac=1, random_state=42).reset_index(drop=True)

n = len(structured_full)

train_end = int(0.8 * n)
val_end = int(0.9 * n)

train_df = structured_full.iloc[:train_end]
val_df   = structured_full.iloc[train_end:val_end]
test_df  = structured_full.iloc[val_end:]

# %%
train_df.to_csv("mv_train.csv", index=False)
val_df.to_csv("mv_val.csv", index=False)
test_df.to_csv("mv_test.csv", index=False)

# %%
len(test_df)
# Out:
# 16262

# %%
len(val_df)
# Out:
# 16262

# %%
train_df
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0        69219    12174269         NaN  32252456  2115-03-05 18:52:00
# 1       374706    16975219         NaN  36792323  2123-11-26 04:52:00
# 2       392693    10199379         NaN  38089639  2161-04-10 13:43:00
# 3       386691    19101434  25207489.0  33105183  2191-05-10 20:19:00
# 4        20499    13593727  25433469.0  34482189  2113-05-24 15:20:00
# ...        ...         ...         ...       ...                  ...
# 130089  270105    18344979  22754681.0  33003986  2148-05-17 13:49:00
# 130090  103723    18521553  24775640.0  38586635  2205-04-24 03:20:00
# 130091  147299    16348266         NaN  39860421  2130-11-08 22:56:00
# 130092   96861    17224704  21140484.0  36602043  2124-11-24 22:46:00
# 130093  257565    16142730         NaN  36957893  2141-12-21 14:16:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ...  \
# 0       2115-03-05 18:54:00          30      F         2115  NaN  ...
# 1       2123-11-26 06:13:00          47      M         2121  NaN  ...
# 2       2161-04-10 13:49:00          30      F         2157  NaN  ...
# 3       2191-05-10 22:27:54          64      M         2188  NaN  ...
# 4       2113-05-24 20:50:19          52      M         2112  NaN  ...
# ...                     ...         ...    ...          ...  ...  ...
# 130089  2148-05-17 21:33:00          70      M         2148  NaN  ...
# 130090  2205-04-24 10:37:00          88      F         2194  NaN  ...
# 130091  2130-11-08 23:01:00          37      M         2129  NaN  ...
# 130092  2124-11-25 08:38:00          70      F         2119  NaN  ...
# 130093  2141-12-21 14:24:00          69      M         2138  NaN  ...
#
#         triage_MAP score_CCI score_CART score_REMS score_NEWS score_NEWS2  \
# 0        94.666667         0          0          0          0           0
# 1       111.333333         1          4          6          3           2
# 2       106.333333         1          0          0          0           0
# 3       109.000000         3          4          5          1           0
# 4        79.666667         4          0          2          0           0
# ...            ...       ...        ...        ...        ...         ...
# 130089  106.666667         3          9          5          0           0
# 130090  108.666667         4          9          8          1           0
# 130091   98.666667         0          0          2          0           0
# 130092   74.333333         3          9          6          2           2
# 130093  103.333333         3          9          5          0           0
#
#        score_MEWS  split                                              notes  \
# 0               1  train  examination ankle ap mortise and lat left indi...
# 1               3  train  indication year old man with right shoulder pa...
# 2               1   test  i ve been getting more i scheduled an appointm...
# 3               1  train  malaise hypotension baradycardia anemia mr is ...
# 4               1  train  esrd mr is a year old male with hep c w fibros...
# ...           ...    ...                                                ...
# 130089          1   test  examination knee ap wb lateral and sunrise lef...
# 130090          1  train  indication with r knee pain s p fall r knee pa...
# 130091          1  train  mr is a with a pmh significant for hiv on haar...
# 130092          1  train  study ct of the paranasal sinuses with contras...
# 130093          1  train  left ankle arthritis with post traumatic left ...
#
#                                            ecg_paths
# 0       ['files/p1217/p12174269/s47575777/47575777']
# 1       ['files/p1697/p16975219/s49058539/49058539']
# 2       ['files/p1019/p10199379/s41948308/41948308']
# 3       ['files/p1910/p19101434/s44754723/44754723']
# 4       ['files/p1359/p13593727/s43147443/43147443']
# ...                                              ...
# 130089  ['files/p1834/p18344979/s44647775/44647775']
# 130090  ['files/p1852/p18521553/s47124485/47124485']
# 130091  ['files/p1634/p16348266/s42455134/42455134']
# 130092  ['files/p1722/p17224704/s47615898/47615898']
# 130093  ['files/p1614/p16142730/s48861282/48861282']
#
# [130094 rows x 129 columns]
