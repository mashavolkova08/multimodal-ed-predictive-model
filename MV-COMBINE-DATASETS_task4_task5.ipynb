# %%
import pandas as pd

# %%
structured_train = pd.read_csv('train.csv')
print(len(structured_train))
structured_test = pd.read_csv('test.csv')
print(len(structured_test))
print(len(structured_train) + len(structured_test))
# Out:
# 359043
# 89761
# 448804

# %%
structured_train
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0       215414    18566742  27103162.0  38538786  2135-07-16 16:08:00
# 1       205452    16853729         NaN  30043998  2178-01-25 05:09:00
# 2       200705    16026698         NaN  39475313  2128-10-19 20:01:00
# 3        87038    15398519  25237915.0  35495155  2147-06-15 09:50:00
# 4       373626    16787687  23674090.0  31087259  2181-03-20 10:38:00
# ...        ...         ...         ...       ...                  ...
# 359038  113182    10249080         NaN  32475431  2116-01-19 23:41:00
# 359039  323227    17819662  21020261.0  31105287  2182-02-08 00:32:00
# 359040  129321    13199993  24770260.0  37954239  2185-03-02 19:21:00
# 359041  167557    10028683         NaN  31802829  2171-12-05 17:36:00
# 359042  300451    13723460  25859289.0  39195476  2161-10-09 20:46:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ...  \
# 0       2135-07-17 01:49:00          58      F         2132  NaN  ...
# 1       2178-01-25 07:05:00          91      F         2169  NaN  ...
# 2       2128-10-19 20:16:00          23      M         2128  NaN  ...
# 3       2147-06-15 15:55:00          57      M         2136  NaN  ...
# 4       2181-03-21 12:55:00          87      F         2176  NaN  ...
# ...                     ...         ...    ...          ...  ...  ...
# 359038  2116-01-19 23:55:00          29      M         2114  NaN  ...
# 359039  2182-02-08 03:31:00          52      M         2182  NaN  ...
# 359040  2185-03-04 15:48:00          37      M         2179  NaN  ...
# 359041  2171-12-05 17:42:00          35      F         2169  NaN  ...
# 359042  2161-10-10 01:26:00          87      M         2160  NaN  ...
#
#        ed_pain_last n_med n_medrecon  triage_MAP score_CCI score_CART  \
# 0          2.127651   5.0        2.0   97.333333         2          4
# 1          2.127651   2.0        3.0  118.333333         7          9
# 2          7.000000   1.0        1.0  116.000000         0         12
# 3          0.000000   7.0       10.0  100.000000        12         16
# 4          0.000000   6.0       13.0   87.000000        11          9
# ...             ...   ...        ...         ...       ...        ...
# 359038     0.000000   0.0        0.0   98.666667         0          0
# 359039     2.127651   2.0        7.0  115.333333         1          0
# 359040     0.000000   7.0        0.0  116.666667         0          0
# 359041     0.000000   3.0       10.0   85.000000         1          0
# 359042     0.000000   3.0        0.0   96.622249        18          9
#
#        score_REMS  score_NEWS  score_NEWS2  score_MEWS
# 0               3           1            1           1
# 1               8           1            0           1
# 2               4           4            4           4
# 3               7           5            3           3
# 4               6           0            0           0
# ...           ...         ...          ...         ...
# 359038          0           0            0           1
# 359039          4           0            0           1
# 359040          2           0            0           1
# 359041          0           0            0           1
# 359042          6           0            0           1
#
# [359043 rows x 126 columns]

# %%
df_ecg = pd.read_csv("master_dataset_ecg_DISPOSITION.csv")
print(len(df_ecg))
df_ecg
# Out:
# 220221
#         level_0  visit_key  subject_id     hadm_id   stay_id  \
# 0             3     335317    10000032  29079034.0  39399961
# 1             4     335318    10000032  25742920.0  35968195
# 2            12     335319    10000117  22927623.0  32642808
# 3            14     335321    10000117  27988844.0  33176849
# 4            17     279332    10000285         NaN  37909301
# ...         ...        ...         ...         ...       ...
# 220216   448963     391557    19999733  27674281.0  30940569
# 220217   448965     167404    19999784  26194817.0  35692999
# 220218   448967     167406    19999784  25715748.0  34149746
# 220219   448969     167408    19999828  25744818.0  32917002
# 220220   448971     335313    19999987  23865745.0  34731548
#
#                      intime              outtime  anchor_age gender  \
# 0       2180-07-23 05:54:00  2180-07-23 14:00:00          52      F
# 1       2180-08-05 20:58:00  2180-08-06 01:44:00          52      F
# 2       2181-11-14 21:51:00  2181-11-15 02:06:42          48      F
# 3       2183-09-18 08:41:00  2183-09-18 20:20:00          48      F
# 4       2159-11-26 14:22:00  2159-11-26 14:44:00          34      M
# ...                     ...                  ...         ...    ...
# 220216  2152-07-08 20:15:00  2152-07-09 03:45:00          19      F
# 220217  2119-06-18 14:21:00  2119-06-18 21:09:29          57      M
# 220218  2119-08-11 09:15:00  2119-08-11 13:40:00          57      M
# 220219  2149-01-08 09:11:00  2149-01-08 18:12:00          46      F
# 220220  2145-11-02 19:28:00  2145-11-02 22:59:00          57      F
#
#         anchor_year  ... ed_heartrate_last ed_resprate_last ed_o2sat_last  \
# 0              2180  ...              96.0             18.0          97.0
# 1              2180  ...              91.0             18.0          99.0
# 2              2174  ...              85.0             21.0          98.0
# 3              2174  ...              88.0             18.0          95.0
# 4              2159  ...              66.0             14.0         100.0
# ...             ...  ...               ...              ...           ...
# 220216         2152  ...              54.0             16.0         100.0
# 220217         2119  ...              75.0             16.0          99.0
# 220218         2119  ...              72.0             16.0         100.0
# 220219         2147  ...             109.0             15.0          96.0
# 220220         2145  ...             103.0             20.0           NaN
#
#        ed_sbp_last ed_dbp_last ed_pain_last n_med n_medrecon  \
# 0             86.0        45.0          NaN   8.0       14.0
# 1             98.0        60.0          NaN   6.0        7.0
# 2            141.0        77.0          0.0   0.0        1.0
# 3            112.0        72.0          0.0   0.0        0.0
# 4            136.0        92.0          1.0   1.0        0.0
# ...            ...         ...          ...   ...        ...
# 220216        93.0        58.0          0.0   6.0        2.0
# 220217       123.0        82.0          0.0   0.0        0.0
# 220218       131.0        92.0          0.0   1.0        8.0
# 220219       111.0        78.0          4.0   8.0       11.0
# 220220       113.0        79.0          NaN   4.0        0.0
#
#                                            ecg_paths  \
# 0       ['files/p1000/p10000032/s44458630/44458630']
# 1       ['files/p1000/p10000032/s40689238/40689238']
# 2       ['files/p1000/p10000117/s45090959/45090959']
# 3       ['files/p1000/p10000117/s48446569/48446569']
# 4       ['files/p1000/p10000285/s42709053/42709053']
# ...                                              ...
# 220216  ['files/p1999/p19999733/s42489677/42489677']
# 220217  ['files/p1999/p19999784/s40734999/40734999']
# 220218  ['files/p1999/p19999784/s47639679/47639679']
# 220219  ['files/p1999/p19999828/s40643529/40643529']
# 220220  ['files/p1999/p19999987/s41190887/41190887']
#
#                                    last_ecg_path
# 0       files/p1000/p10000032/s44458630/44458630
# 1       files/p1000/p10000032/s40689238/40689238
# 2       files/p1000/p10000117/s45090959/45090959
# 3       files/p1000/p10000117/s48446569/48446569
# 4       files/p1000/p10000285/s42709053/42709053
# ...                                          ...
# 220216  files/p1999/p19999733/s42489677/42489677
# 220217  files/p1999/p19999784/s40734999/40734999
# 220218  files/p1999/p19999784/s47639679/47639679
# 220219  files/p1999/p19999828/s40643529/40643529
# 220220  files/p1999/p19999987/s41190887/41190887
#
# [220221 rows x 122 columns]

# %%
import pandas as pd
import ast

df = df_ecg

df["ecg_paths"] = df["ecg_paths"].apply(ast.literal_eval)

df["last_ecg_path"] = df["ecg_paths"].apply(lambda x: x[-1] if isinstance(x, list) and len(x) > 0 else None)

g = df.groupby(["subject_id", "last_ecg_path"])

conflicts = g.filter(
    lambda x: (
        x["outcome_critical"].nunique() > 1
        or x["outcome_hospitalization"].nunique() > 1
    )
)

conflicts
# Out:
# Empty DataFrame
# Columns: [level_0, visit_key, subject_id, hadm_id, stay_id, intime, outtime, anchor_age, gender, anchor_year, dod, admittime, dischtime, deathtime, ethnicity, edregtime, edouttime, insurance, in_year, age, outcome_inhospital_mortality, ed_death, before_ed_mortality, ed_los, intime_icu, time_to_icu_transfer, outcome_icu_transfer_12h, outcome_hospitalization, outcome_critical, n_ed_30d, n_ed_90d, n_ed_365d, next_ed_visit_time, next_ed_visit_time_diff, outcome_ed_revisit_3d, n_hosp_30d, n_hosp_90d, n_hosp_365d, n_icu_30d, n_icu_90d, n_icu_365d, ed_los_hours, time_to_icu_transfer_hours, next_ed_visit_time_diff_days, triage_temperature, triage_heartrate, triage_resprate, triage_o2sat, triage_sbp, triage_dbp, triage_pain, triage_acuity, chiefcomplaint, chiefcom_chest_pain, chiefcom_abdominal_pain, chiefcom_headache, chiefcom_shortness_of_breath, chiefcom_back_pain, chiefcom_cough, chiefcom_nausea_vomiting, chiefcom_fever_chills, chiefcom_syncope, chiefcom_dizziness, cci_MI, cci_CHF, cci_PVD, cci_Stroke, cci_Dementia, cci_Pulmonary, cci_Rheumatic, cci_PUD, cci_Liver1, cci_DM1, cci_DM2, cci_Paralysis, cci_Renal, cci_Cancer1, cci_Liver2, cci_Cancer2, cci_HIV, eci_CHF, eci_Arrhythmia, eci_Valvular, eci_PHTN, eci_PVD, eci_HTN1, eci_HTN2, eci_Paralysis, eci_NeuroOther, eci_Pulmonary, eci_DM1, eci_DM2, eci_Hypothyroid, eci_Renal, eci_Liver, eci_PUD, eci_HIV, eci_Lymphoma, eci_Tumor2, eci_Tumor1, ...]
# Index: []
#
# [0 rows x 122 columns]

# %%
df_notes = pd.read_csv("master_dataset_notes_cleaned_DISPOSITION.csv")
print(len(df_notes))
df_notes
# Out:
# 284627
#          index  subject_id   stay_id  \
# 0       335314    10000032  33258284
# 1       335315    10000032  38112554
# 2       335316    10000032  32952584
# 3       335317    10000032  39399961
# 4       335318    10000032  35968195
# ...        ...         ...       ...
# 284622  167405    19999784  37972930
# 284623  167406    19999784  34149746
# 284624  167407    19999828  30712109
# 284625  167408    19999828  32917002
# 284626  335313    19999987  34731548
#
#                                                     notes  \
# 0       examination liver or gallbladder us single org...
# 1       worsening abd distension and pain hcv cirrhosi...
# 2       abdominal fullness and discomfort with hiv on ...
# 3       examination chest portable ap indication with ...
# 4       altered mental status mrs is a female with hiv...
# ...                                                   ...
# 284622  lle weakness dysphagia up with new difficulty ...
# 284623  intramedullary spinal cord lesion at the conus...
# 284624  indication year old woman with new right 41cm ...
# 284625  on anticoagulation diverticulosis htn copd and...
# 284626  history with left occipital bleeding assess fo...
#
#         outcome_hospitalization  outcome_critical
# 0                          True             False
# 1                          True             False
# 2                          True              True
# 3                          True              True
# 4                          True             False
# ...                         ...               ...
# 284622                     True             False
# 284623                     True             False
# 284624                     True             False
# 284625                     True              True
# 284626                     True              True
#
# [284627 rows x 6 columns]

# %%
df_notes.columns.to_list()
# Out:
# ['index',
#  'subject_id',
#  'stay_id',
#  'notes',
#  'outcome_hospitalization',
#  'outcome_critical']

# %%
conflict_hosp_notes = (
    df_notes.groupby("notes")["outcome_hospitalization"]
    .nunique()
    .loc[lambda x: x > 1]
    .index
)

# find notes with conflicting critical outcomes
conflict_crit_notes = (
    df_notes.groupby("notes")["outcome_critical"]
    .nunique()
    .loc[lambda x: x > 1]
    .index
)

# combine both sets
conflict_notes = set(conflict_hosp_notes).union(set(conflict_crit_notes))

print("Total conflicting note texts:", len(conflict_notes))

# remove them
df_notes_clean = df_notes[~df_notes["notes"].isin(conflict_notes)].copy()

print("Rows before:", len(df_notes))
print("Rows after:", len(df_notes_clean))
# Out:
# Total conflicting note texts: 42
# Rows before: 284627
# Rows after: 284481

# %%
df_notes
# Out:
#          index  subject_id   stay_id  \
# 0       335314    10000032  33258284
# 1       335315    10000032  38112554
# 2       335316    10000032  32952584
# 3       335317    10000032  39399961
# 4       335318    10000032  35968195
# ...        ...         ...       ...
# 284622  167405    19999784  37972930
# 284623  167406    19999784  34149746
# 284624  167407    19999828  30712109
# 284625  167408    19999828  32917002
# 284626  335313    19999987  34731548
#
#                                                     notes  \
# 0       examination liver or gallbladder us single org...
# 1       worsening abd distension and pain hcv cirrhosi...
# 2       abdominal fullness and discomfort with hiv on ...
# 3       examination chest portable ap indication with ...
# 4       altered mental status mrs is a female with hiv...
# ...                                                   ...
# 284622  lle weakness dysphagia up with new difficulty ...
# 284623  intramedullary spinal cord lesion at the conus...
# 284624  indication year old woman with new right 41cm ...
# 284625  on anticoagulation diverticulosis htn copd and...
# 284626  history with left occipital bleeding assess fo...
#
#         outcome_hospitalization  outcome_critical
# 0                          True             False
# 1                          True             False
# 2                          True              True
# 3                          True              True
# 4                          True             False
# ...                         ...               ...
# 284622                     True             False
# 284623                     True             False
# 284624                     True             False
# 284625                     True              True
# 284626                     True              True
#
# [284627 rows x 6 columns]

# %%
df_ecg
# Out:
#         level_0  visit_key  subject_id     hadm_id   stay_id  \
# 0             3     335317    10000032  29079034.0  39399961
# 1             4     335318    10000032  25742920.0  35968195
# 2            12     335319    10000117  22927623.0  32642808
# 3            14     335321    10000117  27988844.0  33176849
# 4            17     279332    10000285         NaN  37909301
# ...         ...        ...         ...         ...       ...
# 220216   448963     391557    19999733  27674281.0  30940569
# 220217   448965     167404    19999784  26194817.0  35692999
# 220218   448967     167406    19999784  25715748.0  34149746
# 220219   448969     167408    19999828  25744818.0  32917002
# 220220   448971     335313    19999987  23865745.0  34731548
#
#                      intime              outtime  anchor_age gender  \
# 0       2180-07-23 05:54:00  2180-07-23 14:00:00          52      F
# 1       2180-08-05 20:58:00  2180-08-06 01:44:00          52      F
# 2       2181-11-14 21:51:00  2181-11-15 02:06:42          48      F
# 3       2183-09-18 08:41:00  2183-09-18 20:20:00          48      F
# 4       2159-11-26 14:22:00  2159-11-26 14:44:00          34      M
# ...                     ...                  ...         ...    ...
# 220216  2152-07-08 20:15:00  2152-07-09 03:45:00          19      F
# 220217  2119-06-18 14:21:00  2119-06-18 21:09:29          57      M
# 220218  2119-08-11 09:15:00  2119-08-11 13:40:00          57      M
# 220219  2149-01-08 09:11:00  2149-01-08 18:12:00          46      F
# 220220  2145-11-02 19:28:00  2145-11-02 22:59:00          57      F
#
#         anchor_year  ... ed_heartrate_last ed_resprate_last ed_o2sat_last  \
# 0              2180  ...              96.0             18.0          97.0
# 1              2180  ...              91.0             18.0          99.0
# 2              2174  ...              85.0             21.0          98.0
# 3              2174  ...              88.0             18.0          95.0
# 4              2159  ...              66.0             14.0         100.0
# ...             ...  ...               ...              ...           ...
# 220216         2152  ...              54.0             16.0         100.0
# 220217         2119  ...              75.0             16.0          99.0
# 220218         2119  ...              72.0             16.0         100.0
# 220219         2147  ...             109.0             15.0          96.0
# 220220         2145  ...             103.0             20.0           NaN
#
#        ed_sbp_last ed_dbp_last ed_pain_last n_med n_medrecon  \
# 0             86.0        45.0          NaN   8.0       14.0
# 1             98.0        60.0          NaN   6.0        7.0
# 2            141.0        77.0          0.0   0.0        1.0
# 3            112.0        72.0          0.0   0.0        0.0
# 4            136.0        92.0          1.0   1.0        0.0
# ...            ...         ...          ...   ...        ...
# 220216        93.0        58.0          0.0   6.0        2.0
# 220217       123.0        82.0          0.0   0.0        0.0
# 220218       131.0        92.0          0.0   1.0        8.0
# 220219       111.0        78.0          4.0   8.0       11.0
# 220220       113.0        79.0          NaN   4.0        0.0
#
#                                          ecg_paths  \
# 0       [files/p1000/p10000032/s44458630/44458630]
# 1       [files/p1000/p10000032/s40689238/40689238]
# 2       [files/p1000/p10000117/s45090959/45090959]
# 3       [files/p1000/p10000117/s48446569/48446569]
# 4       [files/p1000/p10000285/s42709053/42709053]
# ...                                            ...
# 220216  [files/p1999/p19999733/s42489677/42489677]
# 220217  [files/p1999/p19999784/s40734999/40734999]
# 220218  [files/p1999/p19999784/s47639679/47639679]
# 220219  [files/p1999/p19999828/s40643529/40643529]
# 220220  [files/p1999/p19999987/s41190887/41190887]
#
#                                    last_ecg_path
# 0       files/p1000/p10000032/s44458630/44458630
# 1       files/p1000/p10000032/s40689238/40689238
# 2       files/p1000/p10000117/s45090959/45090959
# 3       files/p1000/p10000117/s48446569/48446569
# 4       files/p1000/p10000285/s42709053/42709053
# ...                                          ...
# 220216  files/p1999/p19999733/s42489677/42489677
# 220217  files/p1999/p19999784/s40734999/40734999
# 220218  files/p1999/p19999784/s47639679/47639679
# 220219  files/p1999/p19999828/s40643529/40643529
# 220220  files/p1999/p19999987/s41190887/41190887
#
# [220221 rows x 122 columns]

# %%
structured_train
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0       215414    18566742  27103162.0  38538786  2135-07-16 16:08:00
# 1       205452    16853729         NaN  30043998  2178-01-25 05:09:00
# 2       200705    16026698         NaN  39475313  2128-10-19 20:01:00
# 3        87038    15398519  25237915.0  35495155  2147-06-15 09:50:00
# 4       373626    16787687  23674090.0  31087259  2181-03-20 10:38:00
# ...        ...         ...         ...       ...                  ...
# 359038  113182    10249080         NaN  32475431  2116-01-19 23:41:00
# 359039  323227    17819662  21020261.0  31105287  2182-02-08 00:32:00
# 359040  129321    13199993  24770260.0  37954239  2185-03-02 19:21:00
# 359041  167557    10028683         NaN  31802829  2171-12-05 17:36:00
# 359042  300451    13723460  25859289.0  39195476  2161-10-09 20:46:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ...  \
# 0       2135-07-17 01:49:00          58      F         2132  NaN  ...
# 1       2178-01-25 07:05:00          91      F         2169  NaN  ...
# 2       2128-10-19 20:16:00          23      M         2128  NaN  ...
# 3       2147-06-15 15:55:00          57      M         2136  NaN  ...
# 4       2181-03-21 12:55:00          87      F         2176  NaN  ...
# ...                     ...         ...    ...          ...  ...  ...
# 359038  2116-01-19 23:55:00          29      M         2114  NaN  ...
# 359039  2182-02-08 03:31:00          52      M         2182  NaN  ...
# 359040  2185-03-04 15:48:00          37      M         2179  NaN  ...
# 359041  2171-12-05 17:42:00          35      F         2169  NaN  ...
# 359042  2161-10-10 01:26:00          87      M         2160  NaN  ...
#
#        ed_pain_last n_med n_medrecon  triage_MAP score_CCI score_CART  \
# 0          2.127651   5.0        2.0   97.333333         2          4
# 1          2.127651   2.0        3.0  118.333333         7          9
# 2          7.000000   1.0        1.0  116.000000         0         12
# 3          0.000000   7.0       10.0  100.000000        12         16
# 4          0.000000   6.0       13.0   87.000000        11          9
# ...             ...   ...        ...         ...       ...        ...
# 359038     0.000000   0.0        0.0   98.666667         0          0
# 359039     2.127651   2.0        7.0  115.333333         1          0
# 359040     0.000000   7.0        0.0  116.666667         0          0
# 359041     0.000000   3.0       10.0   85.000000         1          0
# 359042     0.000000   3.0        0.0   96.622249        18          9
#
#        score_REMS  score_NEWS  score_NEWS2  score_MEWS
# 0               3           1            1           1
# 1               8           1            0           1
# 2               4           4            4           4
# 3               7           5            3           3
# 4               6           0            0           0
# ...           ...         ...          ...         ...
# 359038          0           0            0           1
# 359039          4           0            0           1
# 359040          2           0            0           1
# 359041          0           0            0           1
# 359042          6           0            0           1
#
# [359043 rows x 126 columns]

# %%
structured_test
# Out:
#         index  subject_id     hadm_id   stay_id               intime  \
# 0      335316    10000032  29079034.0  32952584  2180-07-22 16:24:00
# 1       56672    10000084  29888819.0  36954971  2160-12-27 18:32:00
# 2           0    10000115         NaN  38081480  2154-12-10 02:04:00
# 3      335319    10000117  22927623.0  32642808  2181-11-14 21:51:00
# 4      335320    10000117         NaN  30632130  2183-07-17 10:30:00
# ...       ...         ...         ...       ...                  ...
# 89756  223462    19999156  22917423.0  39012698  2123-01-27 13:13:00
# 89757  111942    19999175         NaN  34469189  2185-08-13 20:35:00
# 89758  448969    19999270         NaN  30502357  2184-02-11 21:11:00
# 89759   56670    19999466  21397174.0  30402875  2116-08-30 12:11:00
# 89760  167407    19999828  29734428.0  30712109  2147-07-17 17:18:00
#
#                    outtime  anchor_age gender  anchor_year  dod  ...  \
# 0      2180-07-23 05:54:00          52      F         2180  NaN  ...
# 1      2160-12-28 16:07:00          72      M         2160  NaN  ...
# 2      2154-12-10 02:16:00          24      M         2154  NaN  ...
# 3      2181-11-15 02:06:42          48      F         2174  NaN  ...
# 4      2183-07-17 10:40:00          48      F         2174  NaN  ...
# ...                    ...         ...    ...          ...  ...  ...
# 89756  2123-01-27 21:39:00          62      F         2123  NaN  ...
# 89757  2185-08-13 22:24:00          21      M         2185  NaN  ...
# 89758  2184-02-11 21:14:00          33      M         2184  NaN  ...
# 89759  2116-08-31 21:49:00          33      M         2116  NaN  ...
# 89760  2147-07-18 17:34:00          46      F         2147  NaN  ...
#
#       ed_pain_last n_med n_medrecon  triage_MAP score_CCI score_CART  \
# 0         0.000000   2.0       14.0   52.333333         6          4
# 1         0.000000   1.0        6.0   85.000000         4          9
# 2         0.000000   0.0        0.0   87.333333         0          0
# 3         0.000000   0.0        1.0  104.666667         1          4
# 4         0.000000   0.0        0.0   70.000000         1          8
# ...            ...   ...        ...         ...       ...        ...
# 89756     0.000000   1.0        1.0  104.333333         2          4
# 89757     2.127651   0.0        0.0   93.000000         0          0
# 89758     0.000000   0.0        0.0   71.000000         0          4
# 89759     0.000000   3.0        0.0  134.333333         0          0
# 89760     9.000000  11.0        8.0   85.666667         0          0
#
#       score_REMS  score_NEWS  score_NEWS2  score_MEWS
# 0              4           3            3           2
# 1              5           1            0           1
# 2              0           0            0           1
# 3              3           0            0           1
# 4              5           4            4           4
# ...          ...         ...          ...         ...
# 89756          3           0            0           1
# 89757          2           0            0           1
# 89758          0           1            1           1
# 89759          3           0            0           1
# 89760          2           1            1           1
#
# [89761 rows x 126 columns]

# %%
structured_train["split"] = "train"
structured_test["split"] = "test"

structured_full = pd.concat([structured_train, structured_test], ignore_index=True)

# %%
structured_full
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0       215414    18566742  27103162.0  38538786  2135-07-16 16:08:00
# 1       205452    16853729         NaN  30043998  2178-01-25 05:09:00
# 2       200705    16026698         NaN  39475313  2128-10-19 20:01:00
# 3        87038    15398519  25237915.0  35495155  2147-06-15 09:50:00
# 4       373626    16787687  23674090.0  31087259  2181-03-20 10:38:00
# ...        ...         ...         ...       ...                  ...
# 448799  223462    19999156  22917423.0  39012698  2123-01-27 13:13:00
# 448800  111942    19999175         NaN  34469189  2185-08-13 20:35:00
# 448801  448969    19999270         NaN  30502357  2184-02-11 21:11:00
# 448802   56670    19999466  21397174.0  30402875  2116-08-30 12:11:00
# 448803  167407    19999828  29734428.0  30712109  2147-07-17 17:18:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ... n_med  \
# 0       2135-07-17 01:49:00          58      F         2132  NaN  ...   5.0
# 1       2178-01-25 07:05:00          91      F         2169  NaN  ...   2.0
# 2       2128-10-19 20:16:00          23      M         2128  NaN  ...   1.0
# 3       2147-06-15 15:55:00          57      M         2136  NaN  ...   7.0
# 4       2181-03-21 12:55:00          87      F         2176  NaN  ...   6.0
# ...                     ...         ...    ...          ...  ...  ...   ...
# 448799  2123-01-27 21:39:00          62      F         2123  NaN  ...   1.0
# 448800  2185-08-13 22:24:00          21      M         2185  NaN  ...   0.0
# 448801  2184-02-11 21:14:00          33      M         2184  NaN  ...   0.0
# 448802  2116-08-31 21:49:00          33      M         2116  NaN  ...   3.0
# 448803  2147-07-18 17:34:00          46      F         2147  NaN  ...  11.0
#
#        n_medrecon  triage_MAP score_CCI score_CART score_REMS score_NEWS  \
# 0             2.0   97.333333         2          4          3          1
# 1             3.0  118.333333         7          9          8          1
# 2             1.0  116.000000         0         12          4          4
# 3            10.0  100.000000        12         16          7          5
# 4            13.0   87.000000        11          9          6          0
# ...           ...         ...       ...        ...        ...        ...
# 448799        1.0  104.333333         2          4          3          0
# 448800        0.0   93.000000         0          0          2          0
# 448801        0.0   71.000000         0          4          0          1
# 448802        0.0  134.333333         0          0          3          0
# 448803        8.0   85.666667         0          0          2          1
#
#         score_NEWS2  score_MEWS  split
# 0                 1           1  train
# 1                 0           1  train
# 2                 4           4  train
# 3                 3           3  train
# 4                 0           0  train
# ...             ...         ...    ...
# 448799            0           1   test
# 448800            0           1   test
# 448801            1           1   test
# 448802            0           1   test
# 448803            1           1   test
#
# [448804 rows x 127 columns]

# %%
len(structured_full)
# Out:
# 448804

# %%
structured_full["stay_id"].nunique()
# Out:
# 448804

# %%
structured_full = structured_full.merge(
    df_notes[["stay_id", "notes"]],
    on="stay_id",
    how="left"
)

structured_full = structured_full.merge(
    df_ecg[["stay_id", "ecg_paths"]],
    on="stay_id",
    how="left"
)

# %%
structured_full
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0       215414    18566742  27103162.0  38538786  2135-07-16 16:08:00
# 1       205452    16853729         NaN  30043998  2178-01-25 05:09:00
# 2       200705    16026698         NaN  39475313  2128-10-19 20:01:00
# 3        87038    15398519  25237915.0  35495155  2147-06-15 09:50:00
# 4       373626    16787687  23674090.0  31087259  2181-03-20 10:38:00
# ...        ...         ...         ...       ...                  ...
# 448799  223462    19999156  22917423.0  39012698  2123-01-27 13:13:00
# 448800  111942    19999175         NaN  34469189  2185-08-13 20:35:00
# 448801  448969    19999270         NaN  30502357  2184-02-11 21:11:00
# 448802   56670    19999466  21397174.0  30402875  2116-08-30 12:11:00
# 448803  167407    19999828  29734428.0  30712109  2147-07-17 17:18:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ...  \
# 0       2135-07-17 01:49:00          58      F         2132  NaN  ...
# 1       2178-01-25 07:05:00          91      F         2169  NaN  ...
# 2       2128-10-19 20:16:00          23      M         2128  NaN  ...
# 3       2147-06-15 15:55:00          57      M         2136  NaN  ...
# 4       2181-03-21 12:55:00          87      F         2176  NaN  ...
# ...                     ...         ...    ...          ...  ...  ...
# 448799  2123-01-27 21:39:00          62      F         2123  NaN  ...
# 448800  2185-08-13 22:24:00          21      M         2185  NaN  ...
# 448801  2184-02-11 21:14:00          33      M         2184  NaN  ...
# 448802  2116-08-31 21:49:00          33      M         2116  NaN  ...
# 448803  2147-07-18 17:34:00          46      F         2147  NaN  ...
#
#         triage_MAP score_CCI score_CART score_REMS score_NEWS score_NEWS2  \
# 0        97.333333         2          4          3          1           1
# 1       118.333333         7          9          8          1           0
# 2       116.000000         0         12          4          4           4
# 3       100.000000        12         16          7          5           3
# 4        87.000000        11          9          6          0           0
# ...            ...       ...        ...        ...        ...         ...
# 448799  104.333333         2          4          3          0           0
# 448800   93.000000         0          0          2          0           0
# 448801   71.000000         0          4          0          1           1
# 448802  134.333333         0          0          3          0           0
# 448803   85.666667         0          0          2          1           1
#
#        score_MEWS  split                                              notes  \
# 0               1  train                                                NaN
# 1               1  train  examination chest radiograph indication woman ...
# 2               4  train  indication with left arm pain after mva eval f...
# 3               3  train  year old man with a history of severe copd not...
# 4               0  train  examination mr spine w o contrast mr spine ind...
# ...           ...    ...                                                ...
# 448799          1   test  chest two views history female with left sided...
# 448800          1   test  history right hand pain and for punching anoth...
# 448801          1   test                                                NaN
# 448802          1   test                                                NaN
# 448803          1   test  indication year old woman with new right 41cm ...
#
#                                          ecg_paths
# 0                                              NaN
# 1       [files/p1685/p16853729/s43126841/43126841]
# 2                                              NaN
# 3       [files/p1539/p15398519/s48889255/48889255]
# 4       [files/p1678/p16787687/s45350570/45350570]
# ...                                            ...
# 448799  [files/p1999/p19999156/s44234204/44234204]
# 448800                                         NaN
# 448801                                         NaN
# 448802                                         NaN
# 448803                                         NaN
#
# [448804 rows x 129 columns]

# %%
structured_full = structured_full[
    structured_full["notes"].notna() & structured_full["ecg_paths"].notna()
]

# %%
len(structured_full)
# Out:
# 189864

# %%
structured_full["subject_id"].nunique()
# Out:
# 80538

# %%
print(structured_full["outcome_hospitalization"].value_counts())
# Out:
# outcome_hospitalization
# True     128339
# False     61525
# Name: count, dtype: int64

# %%
# shuffle rows
structured_full = structured_full.sample(frac=1, random_state=42).reset_index(drop=True)

n = len(structured_full)

train_end = int(0.8 * n)
val_end = int(0.9 * n)

train_df = structured_full.iloc[:train_end]
val_df   = structured_full.iloc[train_end:val_end]
test_df  = structured_full.iloc[val_end:]

# %%
train_df.to_csv("mv_train_DISPOSITION.csv", index=False)
val_df.to_csv("mv_val_DISPOSITION.csv", index=False)
test_df.to_csv("mv_test_DISPOSITION.csv", index=False)

# %%
len(test_df)
# Out:
# 18987

# %%
len(val_df)
# Out:
# 18986

# %%
train_df
# Out:
#          index  subject_id     hadm_id   stay_id               intime  \
# 0       228428    10870475  24160860.0  32267643  2118-02-13 23:54:00
# 1         7166    11258835         NaN  31208360  2175-04-18 13:54:00
# 2       163449    19301404         NaN  37156637  2123-06-05 16:49:00
# 3        40385    17101381  25853393.0  37075184  2130-05-06 16:51:00
# 4       417338    14508231  29776374.0  32168097  2142-10-14 21:25:00
# ...        ...         ...         ...       ...                  ...
# 151886  158755    18435804  27148607.0  36316746  2173-03-23 21:29:00
# 151887  252500    15199991  20937847.0  35813475  2139-06-21 11:00:00
# 151888  166840    19898562         NaN  36248733  2121-10-03 21:31:00
# 151889  157242    18166964  20398450.0  35637065  2134-12-25 09:46:00
# 151890  260960    16738690  23634483.0  39332443  2159-05-10 17:32:00
#
#                     outtime  anchor_age gender  anchor_year  dod  ...  \
# 0       2118-02-14 15:44:00          47      F         2118  NaN  ...
# 1       2175-04-18 13:55:00          77      F         2175  NaN  ...
# 2       2123-06-05 17:20:00          20      F         2123  NaN  ...
# 3       2130-05-07 00:48:00          43      F         2125  NaN  ...
# 4       2142-10-15 04:11:16          49      F         2135  NaN  ...
# ...                     ...         ...    ...          ...  ...  ...
# 151886  2173-03-24 02:47:04          91      F         2173  NaN  ...
# 151887  2139-06-21 20:58:00          50      M         2139  NaN  ...
# 151888  2121-10-03 21:39:00          30      F         2118  NaN  ...
# 151889  2134-12-26 17:27:00          87      F         2129  NaN  ...
# 151890  2159-05-10 22:17:00          71      F         2159  NaN  ...
#
#         triage_MAP score_CCI score_CART score_REMS score_NEWS score_NEWS2  \
# 0        96.622249         0          0          2          0           0
# 1       127.000000         3          9          8          0           0
# 2       106.000000         0          0          0          1           1
# 3        89.333333         0          0          2          0           0
# 4       127.333333         5          4          5          1           1
# ...            ...       ...        ...        ...        ...         ...
# 151886   72.000000         4          9          6          2           1
# 151887   84.000000         1          4          4          3           3
# 151888   79.666667         0         13          3          4           4
# 151889   79.000000         4          9          8          0           0
# 151890   91.000000         3         17          5          2           2
#
#        score_MEWS  split                                              notes  \
# 0               1  train  examination hand pa lat and oblique left indic...
# 1               1  train  history screening comparison hologic digital s...
# 2               1  train  examination chest frontal and lateral views in...
# 3               1  train  examination bilateral digital diagnostic mammo...
# 4               2  train  examination chest cta indication history with ...
# ...           ...    ...                                                ...
# 151886          2  train  examination liver or gallbladder us single org...
# 151887          3  train  examination bilat lower ext veins indication w...
# 151888          4  train  indication year old woman with ankle pain late...
# 151889          1  train  history lumbar spine fractures with new lso br...
# 151890          2  train  history female with stridor study ct of the ch...
#
#                                          ecg_paths
# 0       [files/p1087/p10870475/s46566754/46566754]
# 1       [files/p1125/p11258835/s41234765/41234765]
# 2       [files/p1930/p19301404/s43791199/43791199]
# 3       [files/p1710/p17101381/s43685824/43685824]
# 4       [files/p1450/p14508231/s44809303/44809303]
# ...                                            ...
# 151886  [files/p1843/p18435804/s40151793/40151793]
# 151887  [files/p1519/p15199991/s48515218/48515218]
# 151888  [files/p1989/p19898562/s41556290/41556290]
# 151889  [files/p1816/p18166964/s49980239/49980239]
# 151890  [files/p1673/p16738690/s42258563/42258563]
#
# [151891 rows x 129 columns]
